# %%
# !pip install langchain langchain-cohere cohere biopython semanticscholar transformers torch sentencepiece -q

# %%
from langchain_cohere import ChatCohere
import cohere
from google.colab import userdata

cohere_api_key = userdata.get('cohere_API_key')
co = cohere.Client(cohere_api_key)
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)

# %%
query = "Articles about menstrual cycle and females"
response = co.generate(
    model = "c4ai-aya-23-35b",
    prompt = f'''You are a Keyword Generator for a keyword search engine. Your job is only to generate relevant keywords that can be plugged into a keyword search engine given a search query.
    Given this search query: "{query}" generate symantically relevant Keywords.''',
    max_tokens=300,
    temperature=0.01,
    k=1,
    stop_sequences=[],
    return_likelihoods='NONE'
)

print(response.generations[0].text)
# Out:
# Sure! Here are some relevant keywords for the given search query:
#
# - "Menstrual cycle phases"
# - "Female reproductive health"
# - "Period tracking"
# - "Menstruation education"
# - "Hormonal changes during menstruation"
# - "Common menstrual issues"
# - "Female-specific health concerns"
# - "Menstrual products and options"
# - "Social impact of menstruation"
# - "Taboos and culture around menstruation"
#
# These keywords should provide a good starting point for a keyword search engine to retrieve relevant articles and information about the menstrual cycle and its relation to female health and experiences.

# %%
import re

keywords_list = re.findall(r'-\s"([^"]+)"', response.generations[0].text)
keywords_list
# Out:
# ['Menstrual cycle phases',
#  'Female reproductive health',
#  'Period tracking',
#  'Menstruation education',
#  'Hormonal changes during menstruation',
#  'Common menstrual issues',
#  'Female-specific health concerns',
#  'Menstrual products and options',
#  'Social impact of menstruation',
#  'Taboos and culture around menstruation']

# %%
from Bio import Entrez, Medline

userdata = {
    'email': '',
    'api_key': ''
}

Entrez.email = userdata.get('email')
Entrez.api_key = userdata.get('api_key')

# %%
import pandas as pd

#ask user to select earliest publication date
publication_date = '2024/01/01'
retmax = 250

unique_pmids = set()
keyword_dictionary_pmids = {}

for kw in keywords_list:
    search_term = kw
    handle = Entrez.esearch(db="pubmed", term=search_term, mindate=publication_date, retmax=retmax)
    record = Entrez.read(handle)
    handle.close()

    keyword_dictionary_pmids[kw] = record["IdList"]

    # Filter out PMIDs that have been already collected
    new_pmids = set(record["IdList"]) - unique_pmids

    print(f"{len(new_pmids)} new results found for Search '{kw}'")

    # Update the set of unique PMIDs
    unique_pmids.update(new_pmids)
# Out:
# 250 new results found for Search 'Menstrual cycle phases'
# 246 new results found for Search 'Female reproductive health'
# 249 new results found for Search 'Period tracking'
# 235 new results found for Search 'Menstruation education'
# 224 new results found for Search 'Hormonal changes during menstruation'
# 241 new results found for Search 'Common menstrual issues'
# 40 new results found for Search 'Female-specific health concerns'
# 56 new results found for Search 'Menstrual products and options'
# 209 new results found for Search 'Social impact of menstruation'
# 9 new results found for Search 'Taboos and culture around menstruation'

# %%
for keyword, pmid_list in keyword_dictionary_pmids.items():
    print(f"Search: {keyword}, \n PMIDs: {len(pmid_list)}")
    print()
# Out:
# Search: Menstrual cycle phases,
#  PMIDs: 250
#
# Search: Female reproductive health,
#  PMIDs: 250
#
# Search: Period tracking,
#  PMIDs: 250
#
# Search: Menstruation education,
#  PMIDs: 250
#
# Search: Hormonal changes during menstruation,
#  PMIDs: 250
#
# Search: Common menstrual issues,
#  PMIDs: 250
#
# Search: Female-specific health concerns,
#  PMIDs: 41
#
# Search: Menstrual products and options,
#  PMIDs: 58
#
# Search: Social impact of menstruation,
#  PMIDs: 250
#
# Search: Taboos and culture around menstruation,
#  PMIDs: 20

# %%
print(len(unique_pmids))
# Out:
# 1759

# %%
import pandas as pd
from Bio import Entrez
from concurrent.futures import ThreadPoolExecutor

# Define a function to fetch article data
def fetch_article_data(pmid):
    try:
        handle = Entrez.efetch(db="pubmed", id=pmid, retmode="xml")
        record = Entrez.read(handle)
        handle.close()

        # Initialize variables with default values
        title = 'Title not available'
        abstract = None
        authors = []
        affiliations = []
        keywords = []
        journal = 'Journal not available'
        pub_year = 'Year not available'

        # Extract data as needed with checks
        if 'PubmedArticle' in record and len(record['PubmedArticle']) > 0:
            citation = record['PubmedArticle'][0]['MedlineCitation']

            if 'Article' in citation:
                article = citation['Article']
                title = article.get('ArticleTitle', 'Title not available')

                # Check if the abstract is available
                if 'Abstract' in article:
                    abstract = article['Abstract']['AbstractText']
                    abstract = ' '.join(abstract) if abstract else None

                # Extract author names & author affiliations
                author_list = article.get('AuthorList', [])
                for author in author_list:
                    if 'LastName' in author and 'Initials' in author:
                        full_name = f"{author['LastName']} {author['Initials']}"
                        authors.append(full_name)
                    if 'AffiliationInfo' in author:
                        affiliation_info = author['AffiliationInfo']
                        if len(affiliation_info) > 0:
                            affiliation_name_first = affiliation_info[0]
                            affiliations.append(affiliation_name_first.get('Affiliation', "Not available"))

                # Extract author keywords
                keyword_list = citation.get('KeywordList', [])
                if len(keyword_list) > 0:
                    for keyword in keyword_list[0]:
                        keywords.append(keyword)

                journal_info = article.get('Journal', {})
                journal = journal_info.get('Title', 'Journal not available')
                issue = journal_info.get('JournalIssue', {})
                pub_date = issue.get('PubDate', {})
                pub_year = pub_date.get('Year', 'Year not available')

        return {
            "PMID": pmid,
            "Title": title,
            "Abstract": abstract,
            "Authors": ['; '.join(authors)],
            "Author Affiliations": ['; '.join(affiliations)],
            "Author Keywords": [';'.join(keywords)],
            "Publication Title": journal,
            "Publication Year": pub_year,
        }

    except Exception as e:
        print(f"Error retrieving data for PMID {pmid}: {str(e)}")
        return None

# Specify the number of concurrent threads
num_threads = 5

# Use ThreadPoolExecutor for concurrent fetching
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Fetch article data concurrently
    results = list(executor.map(fetch_article_data, unique_pmids))

# Remove None values (articles with errors)
results = [result for result in results if result is not None]

# Create the DataFrame
df = pd.DataFrame(results)

# Print the resulting DataFrame
print(df.head())
# Out:
# Error retrieving data for PMID 38260168: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37993900: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35682310: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 17636607: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29479656: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39011939: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38530762: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38484430: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38487254: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36819572: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28725187: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39058707: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 21688870: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38713674: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39078778: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39052648: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39054066: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 26238568: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 24819317: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38019777: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31324419: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36497902: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39047756: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 23480070: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39058720: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 21661301: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39083770: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38621734: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39014295: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28694347: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39030453: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39109159: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36200110: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38635192: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38791820: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37908284: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39080931: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39117891: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33376647: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38966626: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34703414: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37679702: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38987681: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39099159: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39115318: HTTP Error 429: Too Many RequestsError retrieving data for PMID 37559733: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 39092286: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38102308: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32884614: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39061062: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38967967: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33693728: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38769497: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39052669: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37790609: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34280938: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37647115: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38998279: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39108701: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32666247: HTTP Error 429: Too Many RequestsError retrieving data for PMID 32542617: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 39100651: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32736958: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38736830: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39107820: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 22032266: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38393358: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 30898802: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38470671: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39053555: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33347153: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38043451: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35903769: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29030160: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39118058: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38011840: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39062484: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34253260: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38704099: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38073995: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36374543: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28003008: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38047433: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39059146: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39005755: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29216895: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36217280: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37671590: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39101542: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 18646175: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32150950: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39046947: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38900669: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38921120: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39103524: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34796732: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35136477: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37573873: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 27362516: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38263324: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39097899: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39101825: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38961430: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38610011: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38651042: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 20538152: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 24859638: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 17636650: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38397644: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39034871: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36158979: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32661954: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37597024: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38725092: HTTP Error 429: Too Many RequestsError retrieving data for PMID 38775726: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 24482059: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37403058: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39069615: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38337751: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 25370906: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39121172: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38040089: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39063524: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28661550: HTTP Error 429: Too Many RequestsError retrieving data for PMID 38308316: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 30984682: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37482080: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38809480: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33345352: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 6571002: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39053521: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39040529: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 20597621: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38011013: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38306878: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29197048: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38182436: HTTP Error 429: Too Many RequestsError retrieving data for PMID 39108015: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 35000620: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39052781: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38341605: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38991194: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38612482: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38981112: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 12823632: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35936591: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38957411: HTTP Error 429: Too Many RequestsError retrieving data for PMID 39076338: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38713629: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 38358798: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39113162: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37063678: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32885987: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 18590884: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34559839: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38343694: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38604265: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 23816156: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38500914: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39119114: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39018559: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 24902132: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38905372: HTTP Error 429: Too Many RequestsError retrieving data for PMID 39118088: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 39092124: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39103920: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39088214: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39015514: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37699591: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38858641: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36479376: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38953810: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39099271: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38356911: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 20052652: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39095201: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 30815338: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 24041149: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39086419: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38227488: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34668042: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34459348: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38951912: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39004007: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37517569: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39080960: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37538011: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39092785: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39078824: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37568061: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34928413: HTTP Error 429: Too Many RequestsError retrieving data for PMID 38956353: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 31777761: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38742674: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38512821: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38304304: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38993271: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39061194: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35505443: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33230235: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34662662: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38883068: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39058692: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34010788: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39049410: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39120635: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39049099: HTTP Error 429: Too Many RequestsError retrieving data for PMID 38932046: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 39024533: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36303656: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39091439: HTTP Error 429: Too Many RequestsError retrieving data for PMID 32912633: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 37344073: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765018: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39078815: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39069248: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38934552: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36771262: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38435859: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 18400578: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39061239: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35655221: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 24476380: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37409188: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 19588442: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39107329: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31189026: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34161351: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37465433: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39054352: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38666082: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 24918081: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38920026: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36111164: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36072776: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39103034: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 21470552: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39006054: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39036541: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37855335: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38321601: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38956852: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 30898082: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 23034827: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28299789: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38995905: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38066487: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39095891: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28029503: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39075932: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39077074: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31089104: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762835: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37156305: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39081080: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38993933: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34048399: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37544804: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38823422: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 17235660: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37542086: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 20452588: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37646858: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34939899: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39085248: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39104824: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39097955: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34504370: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35902326: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38914596: HTTP Error 429: Too Many RequestsError retrieving data for PMID 38162009: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 39051275: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35243928: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32525776: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37869161: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 27806454: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28566013: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38308560: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35268082: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37639363: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36042475: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37732374: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34973478: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39066797: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 21477684: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38215947: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36082631: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36432444: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39058913: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38021970: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39060289: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37590271: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38887385: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38933610: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38994602: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38313170: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 30395733: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38382644: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35573993: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38890710: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39063436: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38074133: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35659080: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38897447: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38959981: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38501513: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31638946: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38920031: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 21934611: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38176542: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38937735: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38381303: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39093743: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38971516: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29368658: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38374080: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38895644: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39024575: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 26509855: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38018828: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38919370: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31538079: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39083535: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39077686: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29197944: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39092983: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37122530: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31608992: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38122960: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 17106950: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38840125: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38039064: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32398163: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38279180: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33399426: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39026943: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31528200: HTTP Error 429: Too Many RequestsError retrieving data for PMID 39097871: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 38223363: HTTP Error 429: Too Many RequestsError retrieving data for PMID 39103847: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 39117023: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38932534: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33414830: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38744159: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36304012: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39106314: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38653456: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38518993: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39109153: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38559249: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37798550: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39088413: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33347159: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39094055: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 24030217: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38152361: HTTP Error 429: Too Many RequestsError retrieving data for PMID 38267033: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 19303945: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38178979: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39087914: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36318501: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39054429: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39014375: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 25488557: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36401325: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38251290: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38110672: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37441516: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37134124: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36994287: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38920510: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39039530: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37487868: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38971571: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39085959: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35607470: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 18849865: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38310222: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37907067: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32744978: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34895210: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37282979: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 19643648: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38681316: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39112531: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31424731: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38976266: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 11251696: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39001919: HTTP Error 429: Too Many RequestsError retrieving data for PMID 39110462: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 39117221: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38982530: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28115328: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35455295: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34754844: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39055962: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 17543131: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34945077: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 24044770: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33347179: HTTP Error 429: Too Many RequestsError retrieving data for PMID 19630353: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 39093859: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38987707: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34806189: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38595611: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36293136: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39071517: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38259036: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39106340: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31284734: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35464571: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38597153: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38529946: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39067321: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39049029: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38894975: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38213268: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34623259: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 30918678: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31536191: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37563987: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38188121: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39086703: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33347155: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39092629: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39063645: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39028554: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38106634: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37211900: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29345727: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33105739: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 17560123: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38657463: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 31808846: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33347163: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37889545: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38552916: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37464435: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32386360: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 27189381: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 22895965: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39008353: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37637817: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39016497: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38948269: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 20661136: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38610770: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33898700: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33122150: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34930318: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37787277: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38907643: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38966472: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38342313: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34574685: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39019274: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33347186: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38677174: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38535418: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 19370619: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38394159: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39002978: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29940996: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29687205: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33347210: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38654586: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39068210: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35031306: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39080939: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39072797: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 30830232: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36730352: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 25903531: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 18657019: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32894120: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 21044726: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39039518: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39114180: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36436072: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36769869: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38311716: HTTP Error 429: Too Many RequestsError retrieving data for PMID 27824744: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 38740361: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38844394: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38967202: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38452605: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38114976: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38735231: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36678300: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33044248: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38442970: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38807333: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38948295: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36685066: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 22002088: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38928969: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38717226: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38596640: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39037645: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34140633: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38545652: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28939480: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38956514: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39055565: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33245019: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 33983443: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38952000: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37849409: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38372528: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37584937: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38470472: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39118774: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37242122: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 32190896: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35726229: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39092781: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 22052698: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39087475: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38361840: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37648988: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 26242650: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29866728: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39075579: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 18646133: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39071069: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39059985: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37658371: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39041357: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 26718530: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39111372: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38650786: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39080771: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35882755: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39011080: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39112528: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38206269: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38277851: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 18049984: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37255590: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 18605512: HTTP Error 429: Too Many RequestsError retrieving data for PMID 38024903: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 37658959: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35143978: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 28846801: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 19910321: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 34991413: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38138175: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 26051565: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39053138: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39003889: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39051002: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 36251373: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 30620772: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 25781065: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38558945: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39049035: HTTP Error 429: Too Many RequestsError retrieving data for PMID 35320150: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 21601786: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38455622: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 21040234: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38812164: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38548626: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39107015: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 39055234: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35283044: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 29486748: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 37654520: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 35912083: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38617267: HTTP Error 429: Too Many Requests
#        PMID                                              Title  \
# 0  33154830  Change in Estradiol Levels among Premenopausal...
# 1  20207519  Age at menarche and premenstrual syndrome in a...
# 2  38951612  Archaeological evidence of an ethnographically...
# 3  39014128  Impact of the 2008 <math xmlns="http://www.w3....
# 4  26670027  Characteristics of the menstrual cycle in 13-y...
#
#                                             Abstract  \
# 0  The combination of luteinizing hormone-releasi...
# 1  The issues involving menstruation are the topi...
# 2  In societies without writing, ethnographically...
# 3  Tectonic plate motions drive the earthquake cy...
# 4  This study aimed to investigate the characteri...
#
#                                              Authors  \
# 0  [Lee YJ; Wu ZY; Kim HJ; Lee JW; Chung IY; Kim ...
# 1              [Ibralic I; Sinanovic O; Memisevic H]
# 2  [David B; Mullett R; Wright N; Stephenson B; A...
# 3  [Iaffaldano G; Martin de Blas J; Rui X; Stamps...
# 4  [Hoppenbrouwers K; Roelants M; Meuleman C; Rij...
#
#                                  Author Affiliations  \
# 0  [Division of Breast Surgery, Department of Sur...
# 1  [Center Vladimir Nazor, Sarajevo, Bosnia and H...
# 2  [Monash Indigenous Studies Centre, Monash Univ...
# 3  [Department of Chemistry, Life Science and Env...
# 4  [Centre of Environment and Health, Department ...
#
#                                      Author Keywords  \
# 0  [Antineoplastic agents;Breast neoplasms;Gonado...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [Impact on social life;Menstrual cycle charact...
#
#                         Publication Title Publication Year
# 0                Journal of breast cancer             2020
# 1  Research in developmental disabilities             2010
# 2                  Nature human behaviour             2024
# 3                      Scientific reports             2024
# 4          European journal of pediatrics             2016

# %%
len(df)
# Out:
# 1190

# %%
df.head()
# Out:
#        PMID                                              Title  \
# 0  33154830  Change in Estradiol Levels among Premenopausal...
# 1  20207519  Age at menarche and premenstrual syndrome in a...
# 2  38951612  Archaeological evidence of an ethnographically...
# 3  39014128  Impact of the 2008 <math xmlns="http://www.w3....
# 4  26670027  Characteristics of the menstrual cycle in 13-y...
#
#                                             Abstract  \
# 0  The combination of luteinizing hormone-releasi...
# 1  The issues involving menstruation are the topi...
# 2  In societies without writing, ethnographically...
# 3  Tectonic plate motions drive the earthquake cy...
# 4  This study aimed to investigate the characteri...
#
#                                              Authors  \
# 0  [Lee YJ; Wu ZY; Kim HJ; Lee JW; Chung IY; Kim ...
# 1              [Ibralic I; Sinanovic O; Memisevic H]
# 2  [David B; Mullett R; Wright N; Stephenson B; A...
# 3  [Iaffaldano G; Martin de Blas J; Rui X; Stamps...
# 4  [Hoppenbrouwers K; Roelants M; Meuleman C; Rij...
#
#                                  Author Affiliations  \
# 0  [Division of Breast Surgery, Department of Sur...
# 1  [Center Vladimir Nazor, Sarajevo, Bosnia and H...
# 2  [Monash Indigenous Studies Centre, Monash Univ...
# 3  [Department of Chemistry, Life Science and Env...
# 4  [Centre of Environment and Health, Department ...
#
#                                      Author Keywords  \
# 0  [Antineoplastic agents;Breast neoplasms;Gonado...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [Impact on social life;Menstrual cycle charact...
#
#                         Publication Title Publication Year
# 0                Journal of breast cancer             2020
# 1  Research in developmental disabilities             2010
# 2                  Nature human behaviour             2024
# 3                      Scientific reports             2024
# 4          European journal of pediatrics             2016

# %%
df.to_csv('entrez_data.csv')

# %%
from semanticscholar import SemanticScholar
sch = SemanticScholar()
results = sch.search_paper("Menstrual Cycle and females")
print(f'{results.total} results.')
# Out:
# 11417 results.

# %%
import pandas as pd

# Initialize an empty list to store the data
data = []

for i in results:
    try:
        # Access attributes directly
        pmid = getattr(i, 'externalIds', {}).get('PubMed', '')
        url = "https://pubmed.ncbi.nlm.nih.gov/" + str(pmid)
    except:
        url = getattr(i, 'url', '')

    # Collect data into a dictionary
    entry = {
        'title': getattr(i, 'title', ''),
        'abstract': getattr(i, 'abstract', ''),
        'authors': [j.name for j in getattr(i, 'authors', [])],
        'url': url,
        'Publication Year': getattr(i, 'year', ''),
        'Publication Title': getattr(i, 'journal', '')
    }
    # Append the dictionary to the list
    data.append(entry)

# Create the DataFrame from the list of dictionaries
df2 = pd.DataFrame(data)

# Print the resulting DataFrame
print(df2.head())
# Out:
#                                                title  \
# 0  Urinary steroid profile in females - the impac...
# 1  Menstrual Cycle Phases Influence on Cardioresp...
# 2  Effects of menstrual cycle and neuroticism on ...
# 3  The Effect of the Menstrual Cycle and Oral Con...
# 4  Ethanol Elimination in Males and Females: Rela...
#
#                                             abstract  \
# 0  Today's doping tests involving longitudinal mo...
# 1  The aim of this study was to analyse the impac...
# 2                                               None
# 3  Most reproductive-aged women are exposed to fl...
# 4  Ethanol pharmacokinetics were determined follo...
#
#                                              authors  \
# 0  [J. Mullen, J. Thörngren, J. Schulze, M. Erics...
# 1  [B. Rael, V. M. Alfaro-Magallanes, N. Romero-P...
# 2                [Mengying Wu, R. Zhou, Yamei Huang]
# 3  [B. Thompson, Kaitlyn B Drover, Rhiannon Stell...
# 4    [A. Marshall, D. Kingstone, M. Boss, M. Morgan]
#
#                                         url  Publication Year  \
# 0  https://pubmed.ncbi.nlm.nih.gov/27758048            2017.0
# 1  https://pubmed.ncbi.nlm.nih.gov/33498274            2021.0
# 2  https://pubmed.ncbi.nlm.nih.gov/25312202            2014.0
# 3  https://pubmed.ncbi.nlm.nih.gov/34682310            2021.0
# 4   https://pubmed.ncbi.nlm.nih.gov/6618437            2007.0
#
#                                    Publication Title
# 0  {'name': 'Drug testing and analysis', 'pages':...
# 1  {'name': 'International Journal of Environment...
# 2  {'name': 'International journal of psychophysi...
# 3  {'name': 'International Journal of Environment...
# 4              {'name': 'Hepatology', 'volume': '3'}

# %%
df2.head()
# Out:
#                                                title  \
# 0  Urinary steroid profile in females - the impac...
# 1  Menstrual Cycle Phases Influence on Cardioresp...
# 2  Effects of menstrual cycle and neuroticism on ...
# 3  The Effect of the Menstrual Cycle and Oral Con...
# 4  Ethanol Elimination in Males and Females: Rela...
#
#                                             abstract  \
# 0  Today's doping tests involving longitudinal mo...
# 1  The aim of this study was to analyse the impac...
# 2                                               None
# 3  Most reproductive-aged women are exposed to fl...
# 4  Ethanol pharmacokinetics were determined follo...
#
#                                              authors  \
# 0  [J. Mullen, J. Thörngren, J. Schulze, M. Erics...
# 1  [B. Rael, V. M. Alfaro-Magallanes, N. Romero-P...
# 2                [Mengying Wu, R. Zhou, Yamei Huang]
# 3  [B. Thompson, Kaitlyn B Drover, Rhiannon Stell...
# 4    [A. Marshall, D. Kingstone, M. Boss, M. Morgan]
#
#                                         url  Publication Year  \
# 0  https://pubmed.ncbi.nlm.nih.gov/27758048            2017.0
# 1  https://pubmed.ncbi.nlm.nih.gov/33498274            2021.0
# 2  https://pubmed.ncbi.nlm.nih.gov/25312202            2014.0
# 3  https://pubmed.ncbi.nlm.nih.gov/34682310            2021.0
# 4   https://pubmed.ncbi.nlm.nih.gov/6618437            2007.0
#
#                                    Publication Title
# 0  {'name': 'Drug testing and analysis', 'pages':...
# 1  {'name': 'International Journal of Environment...
# 2  {'name': 'International journal of psychophysi...
# 3  {'name': 'International Journal of Environment...
# 4              {'name': 'Hepatology', 'volume': '3'}

# %%
df1 = pd.read_csv('entrez_data.csv')

# %%
len(df1)
# Out:
# 1190

# %%
df1['url'] = df1['PMID'].apply(lambda x: "https://pubmed.ncbi.nlm.nih.gov/"+str(x))
df1.head()
# Out:
#    Unnamed: 0      PMID                                              Title  \
# 0           0  33154830  Change in Estradiol Levels among Premenopausal...
# 1           1  20207519  Age at menarche and premenstrual syndrome in a...
# 2           2  38951612  Archaeological evidence of an ethnographically...
# 3           3  39014128  Impact of the 2008 <math xmlns="http://www.w3....
# 4           4  26670027  Characteristics of the menstrual cycle in 13-y...
#
#                                             Abstract  \
# 0  The combination of luteinizing hormone-releasi...
# 1  The issues involving menstruation are the topi...
# 2  In societies without writing, ethnographically...
# 3  Tectonic plate motions drive the earthquake cy...
# 4  This study aimed to investigate the characteri...
#
#                                              Authors  \
# 0  ['Lee YJ; Wu ZY; Kim HJ; Lee JW; Chung IY; Kim...
# 1            ['Ibralic I; Sinanovic O; Memisevic H']
# 2  ['David B; Mullett R; Wright N; Stephenson B; ...
# 3  ['Iaffaldano G; Martin de Blas J; Rui X; Stamp...
# 4  ["Hoppenbrouwers K; Roelants M; Meuleman C; Ri...
#
#                                  Author Affiliations  \
# 0  ['Division of Breast Surgery, Department of Su...
# 1  ['Center Vladimir Nazor, Sarajevo, Bosnia and ...
# 2  ['Monash Indigenous Studies Centre, Monash Uni...
# 3  ['Department of Chemistry, Life Science and En...
# 4  ['Centre of Environment and Health, Department...
#
#                                      Author Keywords  \
# 0  ['Antineoplastic agents;Breast neoplasms;Gonad...
# 1                                               ['']
# 2                                               ['']
# 3                                               ['']
# 4  ['Impact on social life;Menstrual cycle charac...
#
#                         Publication Title Publication Year  \
# 0                Journal of breast cancer             2020
# 1  Research in developmental disabilities             2010
# 2                  Nature human behaviour             2024
# 3                      Scientific reports             2024
# 4          European journal of pediatrics             2016
#
#                                         url
# 0  https://pubmed.ncbi.nlm.nih.gov/33154830
# 1  https://pubmed.ncbi.nlm.nih.gov/20207519
# 2  https://pubmed.ncbi.nlm.nih.gov/38951612
# 3  https://pubmed.ncbi.nlm.nih.gov/39014128
# 4  https://pubmed.ncbi.nlm.nih.gov/26670027

# %%
# Inspect columns in both DataFrames
print("df1 columns:", df1.columns)
print("df2 columns:", df2.columns)

# Define columns to select based on the actual columns present in both DataFrames
common_columns = ['PMID', 'Title', 'Abstract', 'Authors', 'Publication Year', 'url']

# Ensure that the selected columns exist in both DataFrames
df1_columns = [col for col in common_columns if col in df1.columns]
df2_columns = [col for col in common_columns if col in df2.columns]

# Combine the DataFrames without duplicates based on PMID
combined_df = pd.concat([
    df1.loc[:, df1_columns],
    df2.loc[:, df2_columns]
], ignore_index=True).drop_duplicates(subset='PMID')

# Print the combined DataFrame
print(combined_df.head())
# Out:
# df1 columns: Index(['Unnamed: 0', 'PMID', 'Title', 'Abstract', 'Authors',
#        'Author Affiliations', 'Author Keywords', 'Publication Title',
#        'Publication Year', 'url', 'Publication Date'],
#       dtype='object')
# df2 columns: Index(['title', 'abstract', 'authors', 'url', 'Publication Year',
#        'Publication Title', 'Publication Date', 'PMID', 'Title', 'Abstract',
#        'Authors'],
#       dtype='object')
#        PMID                                              Title  \
# 0  33154830  Change in Estradiol Levels among Premenopausal...
# 1  20207519  Age at menarche and premenstrual syndrome in a...
# 2  38951612  Archaeological evidence of an ethnographically...
# 3  39014128  Impact of the 2008 <math xmlns="http://www.w3....
# 4  26670027  Characteristics of the menstrual cycle in 13-y...
#
#                                             Abstract  \
# 0  The combination of luteinizing hormone-releasi...
# 1  The issues involving menstruation are the topi...
# 2  In societies without writing, ethnographically...
# 3  Tectonic plate motions drive the earthquake cy...
# 4  This study aimed to investigate the characteri...
#
#                                              Authors Publication Year  \
# 0  ['Lee YJ; Wu ZY; Kim HJ; Lee JW; Chung IY; Kim...             2020
# 1            ['Ibralic I; Sinanovic O; Memisevic H']             2010
# 2  ['David B; Mullett R; Wright N; Stephenson B; ...             2024
# 3  ['Iaffaldano G; Martin de Blas J; Rui X; Stamp...             2024
# 4  ["Hoppenbrouwers K; Roelants M; Meuleman C; Ri...             2016
#
#                                         url
# 0  https://pubmed.ncbi.nlm.nih.gov/33154830
# 1  https://pubmed.ncbi.nlm.nih.gov/20207519
# 2  https://pubmed.ncbi.nlm.nih.gov/38951612
# 3  https://pubmed.ncbi.nlm.nih.gov/39014128
# 4  https://pubmed.ncbi.nlm.nih.gov/26670027

# %%
combined_df.head()
# Out:
#        PMID                                              Title  \
# 0  33154830  Change in Estradiol Levels among Premenopausal...
# 1  20207519  Age at menarche and premenstrual syndrome in a...
# 2  38951612  Archaeological evidence of an ethnographically...
# 3  39014128  Impact of the 2008 <math xmlns="http://www.w3....
# 4  26670027  Characteristics of the menstrual cycle in 13-y...
#
#                                             Abstract  \
# 0  The combination of luteinizing hormone-releasi...
# 1  The issues involving menstruation are the topi...
# 2  In societies without writing, ethnographically...
# 3  Tectonic plate motions drive the earthquake cy...
# 4  This study aimed to investigate the characteri...
#
#                                              Authors Publication Year  \
# 0  ['Lee YJ; Wu ZY; Kim HJ; Lee JW; Chung IY; Kim...             2020
# 1            ['Ibralic I; Sinanovic O; Memisevic H']             2010
# 2  ['David B; Mullett R; Wright N; Stephenson B; ...             2024
# 3  ['Iaffaldano G; Martin de Blas J; Rui X; Stamp...             2024
# 4  ["Hoppenbrouwers K; Roelants M; Meuleman C; Ri...             2016
#
#                                         url
# 0  https://pubmed.ncbi.nlm.nih.gov/33154830
# 1  https://pubmed.ncbi.nlm.nih.gov/20207519
# 2  https://pubmed.ncbi.nlm.nih.gov/38951612
# 3  https://pubmed.ncbi.nlm.nih.gov/39014128
# 4  https://pubmed.ncbi.nlm.nih.gov/26670027

# %%
combined_df['Title + Abstract'] = combined_df['Title'] + ' ' + combined_df['Abstract'].fillna('')
combined_df.head()
# Out:
#        PMID                                              Title  \
# 0  33154830  Change in Estradiol Levels among Premenopausal...
# 1  20207519  Age at menarche and premenstrual syndrome in a...
# 2  38951612  Archaeological evidence of an ethnographically...
# 3  39014128  Impact of the 2008 <math xmlns="http://www.w3....
# 4  26670027  Characteristics of the menstrual cycle in 13-y...
#
#                                             Abstract  \
# 0  The combination of luteinizing hormone-releasi...
# 1  The issues involving menstruation are the topi...
# 2  In societies without writing, ethnographically...
# 3  Tectonic plate motions drive the earthquake cy...
# 4  This study aimed to investigate the characteri...
#
#                                              Authors Publication Year  \
# 0  ['Lee YJ; Wu ZY; Kim HJ; Lee JW; Chung IY; Kim...             2020
# 1            ['Ibralic I; Sinanovic O; Memisevic H']             2010
# 2  ['David B; Mullett R; Wright N; Stephenson B; ...             2024
# 3  ['Iaffaldano G; Martin de Blas J; Rui X; Stamp...             2024
# 4  ["Hoppenbrouwers K; Roelants M; Meuleman C; Ri...             2016
#
#                                         url  \
# 0  https://pubmed.ncbi.nlm.nih.gov/33154830
# 1  https://pubmed.ncbi.nlm.nih.gov/20207519
# 2  https://pubmed.ncbi.nlm.nih.gov/38951612
# 3  https://pubmed.ncbi.nlm.nih.gov/39014128
# 4  https://pubmed.ncbi.nlm.nih.gov/26670027
#
#                                     Title + Abstract
# 0  Change in Estradiol Levels among Premenopausal...
# 1  Age at menarche and premenstrual syndrome in a...
# 2  Archaeological evidence of an ethnographically...
# 3  Impact of the 2008 <math xmlns="http://www.w3....
# 4  Characteristics of the menstrual cycle in 13-y...

# %%
combined_df.to_csv('pre_final.csv')

# %%
df = pd.read_csv('/content/pre_final.csv')

# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config

model = T5ForConditionalGeneration.from_pretrained('t5-small')
tokenizer = T5Tokenizer.from_pretrained('t5-small')
device = torch.device('cpu')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
text = """
Python is an interpreted high-level general-purpose programming language. Its design philosophy emphasizes code readability with its use of significant indentation. Its language constructs as well as its object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects.[30]

Python is dynamically-typed and garbage-collected. It supports multiple programming paradigms, including structured (particularly, procedural), object-oriented and functional programming. It is often described as a "batteries included" language due to its comprehensive standard library.[31]

Guido van Rossum began working on Python in the late 1980s, as a successor to the ABC programming language, and first released it in 1991 as Python 0.9.0.[32] Python 2.0 was released in 2000 and introduced new features, such as list comprehensions and a garbage collection system using reference counting. Python 3.0 was released in 2008 and was a major revision of the language that is not completely backward-compatible. Python 2 was discontinued with version 2.7.18 in 2020.[33]

Python consistently ranks as one of the most popular programming languages.[34][35][36][37]"""

preprocessed_text = text.strip().replace('\n','')

t5_input_text = 'summarize: ' + preprocessed_text

tokenized_text = tokenizer.encode(t5_input_text, return_tensors='pt', max_length=300).to(device)

summary_ids = model.generate(tokenized_text, min_length=30, max_length=300)

summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

summary
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# 'Python is a general-purpose programming language. it supports multiple programming paradigms, including structured, object-oriented and functional programming. it is often described as a "batteries included" language due to its comprehensive standard library.'

# %%
count = 0
# Define the summarization function
def summarize_text(text):
    global count
    count +=1
    if count == 2:
      print("Its working")
    if count%100 == 0:
      print(f"{count} summarized")

    # Check if the text is NaN (float) or None
    if pd.isna(text) or text is None:
        return ""  # Return an empty string for missing or None values
    preprocessed_text = str(text).strip().replace('\n', '')  # Convert to string and preprocess
    t5_input_text = 'summarize: ' + preprocessed_text
    tokenized_text = tokenizer.encode(
        t5_input_text,
        return_tensors='pt',
        max_length=350,
        truncation=True  # Explicitly enable truncation
    ).to(device)
    summary_ids = model.generate(tokenized_text, min_length=30, max_length=350)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    return summary

# Apply the summarization function to the "Abstract" column
df['Summarized'] = df['Title + Abstract'].apply(summarize_text)

df.head()
# Out:
# Its working
# 100 summarized
# 200 summarized
# 300 summarized
# 400 summarized
# 500 summarized
# 600 summarized
# 700 summarized
# 800 summarized
# 900 summarized
# 1000 summarized
# 1100 summarized
#    Unnamed: 0        PMID                                              Title  \
# 0           0  33154830.0  Change in Estradiol Levels among Premenopausal...
# 1           1  20207519.0  Age at menarche and premenstrual syndrome in a...
# 2           2  38951612.0  Archaeological evidence of an ethnographically...
# 3           3  39014128.0  Impact of the 2008 <math xmlns="http://www.w3....
# 4           4  26670027.0  Characteristics of the menstrual cycle in 13-y...
#
#                                             Abstract  \
# 0  The combination of luteinizing hormone-releasi...
# 1  The issues involving menstruation are the topi...
# 2  In societies without writing, ethnographically...
# 3  Tectonic plate motions drive the earthquake cy...
# 4  This study aimed to investigate the characteri...
#
#                                              Authors Publication Year  \
# 0  ['Lee YJ; Wu ZY; Kim HJ; Lee JW; Chung IY; Kim...             2020
# 1            ['Ibralic I; Sinanovic O; Memisevic H']             2010
# 2  ['David B; Mullett R; Wright N; Stephenson B; ...             2024
# 3  ['Iaffaldano G; Martin de Blas J; Rui X; Stamp...             2024
# 4  ["Hoppenbrouwers K; Roelants M; Meuleman C; Ri...             2016
#
#                                         url  \
# 0  https://pubmed.ncbi.nlm.nih.gov/33154830
# 1  https://pubmed.ncbi.nlm.nih.gov/20207519
# 2  https://pubmed.ncbi.nlm.nih.gov/38951612
# 3  https://pubmed.ncbi.nlm.nih.gov/39014128
# 4  https://pubmed.ncbi.nlm.nih.gov/26670027
#
#                                     Title + Abstract  \
# 0  Change in Estradiol Levels among Premenopausal...
# 1  Age at menarche and premenstrual syndrome in a...
# 2  Archaeological evidence of an ethnographically...
# 3  Impact of the 2008 <math xmlns="http://www.w3....
# 4  Characteristics of the menstrual cycle in 13-y...
#
#                                           Summarized
# 0  318 patients were included in the study and an...
# 1  the study was conducted in a study of 31 adole...
# 2  ethnographicly documented rituals date back to...
# 3  tectonic plate motions drive the earthquake cy...
# 4  study aims to investigate the characteristics ...

# %%
df.to_csv('data.csv')
